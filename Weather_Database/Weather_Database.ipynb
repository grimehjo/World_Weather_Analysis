# %%
import pandas as pd
import numpy as np

# %%
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

lat_lngs = zip(lats, lngs)
lat_lngs

# %%
coordinates = list(lat_lngs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 743

# %%
import requests

# %%
from config import weather_api_key

# %%
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_current_descrip = city_weather["weather"][0]["description"]
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Current Description": city_current_descrip})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | mataura
# Processing Record 2 of Set 1 | nizhniy odes
# Processing Record 3 of Set 1 | sepatan
# Processing Record 4 of Set 1 | laguna
# Processing Record 5 of Set 1 | tasiilaq
# Processing Record 6 of Set 1 | talcahuano
# Processing Record 7 of Set 1 | rikitea
# Processing Record 8 of Set 1 | lebu
# Processing Record 9 of Set 1 | oktyabrskoye
# Processing Record 10 of Set 1 | carnarvon
# Processing Record 11 of Set 1 | busselton
# Processing Record 12 of Set 1 | albany
# Processing Record 13 of Set 1 | hobart
# Processing Record 14 of Set 1 | vila velha
# Processing Record 15 of Set 1 | nuqui
# Processing Record 16 of Set 1 | hirara
# Processing Record 17 of Set 1 | abu samrah
# Processing Record 18 of Set 1 | yellowknife
# Processing Record 19 of Set 1 | hilo
# Processing Record 20 of Set 1 | kirov
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | cherskiy
# Processing Record 23 of Set 1 | padang
# Processing Record 24 of Set 1 | santa barbara
# Processing Record 25 of Set 1 | camacha
# Processing Record 26 of Set 1 | hasaki
# Processing Record 27 of Set 1 | butaritari
# Processing Record 28 of Set 1 | provideniya
# Processing Record 29 of Set 1 | agadez
# Processing Record 30 of Set 1 | ushuaia
# Processing Record 31 of Set 1 | airai
# Processing Record 32 of Set 1 | morondava
# Processing Record 33 of Set 1 | baiao
# Processing Record 34 of Set 1 | altagracia de orituco
# Processing Record 35 of Set 1 | punta arenas
# Processing Record 36 of Set 1 | ribeira grande
# Processing Record 37 of Set 1 | roma
# Processing Record 38 of Set 1 | high level
# Processing Record 39 of Set 1 | sabang
# Processing Record 40 of Set 1 | longyearbyen
# Processing Record 41 of Set 1 | bredasdorp
# Processing Record 42 of Set 1 | kashi
# Processing Record 43 of Set 1 | igarka
# Processing Record 44 of Set 1 | torbay
# Processing Record 45 of Set 1 | nikolskoye
# Processing Record 46 of Set 1 | sunland park
# Processing Record 47 of Set 1 | castro
# Processing Record 48 of Set 1 | kampong thum
# Processing Record 49 of Set 1 | thompson
# Processing Record 50 of Set 1 | bluff
# Processing Record 1 of Set 2 | linxia
# Processing Record 2 of Set 2 | grindavik
# Processing Record 3 of Set 2 | hermanus
# Processing Record 4 of Set 2 | codrington
# Processing Record 5 of Set 2 | east london
# Processing Record 6 of Set 2 | strezhevoy
# Processing Record 7 of Set 2 | bambous virieux
# Processing Record 8 of Set 2 | port elizabeth
# Processing Record 9 of Set 2 | beringovskiy
# Processing Record 10 of Set 2 | goderich
# Processing Record 11 of Set 2 | iqaluit
# Processing Record 12 of Set 2 | rio grande
# Processing Record 13 of Set 2 | abu kamal
# Processing Record 14 of Set 2 | ushtobe
# Processing Record 15 of Set 2 | caravelas
# Processing Record 16 of Set 2 | new norfolk
# Processing Record 17 of Set 2 | thinadhoo
# Processing Record 18 of Set 2 | inirida
# Processing Record 19 of Set 2 | marystown
# Processing Record 20 of Set 2 | faya
# Processing Record 21 of Set 2 | wanaka
# Processing Record 22 of Set 2 | cabo san lucas
# Processing Record 23 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 24 of Set 2 | kodiak
# Processing Record 25 of Set 2 | nanakuli
# Processing Record 26 of Set 2 | acapulco
# Processing Record 27 of Set 2 | cidreira
# Processing Record 28 of Set 2 | ancud
# Processing Record 29 of Set 2 | khatanga
# Processing Record 30 of Set 2 | shenjiamen
# Processing Record 31 of Set 2 | san cristobal
# Processing Record 32 of Set 2 | eskil
# Processing Record 33 of Set 2 | cape town
# Processing Record 34 of Set 2 | mys shmidta
# City not found. Skipping...
# Processing Record 35 of Set 2 | nonoichi
# Processing Record 36 of Set 2 | chokurdakh
# Processing Record 37 of Set 2 | tahta
# Processing Record 38 of Set 2 | chaguanas
# Processing Record 39 of Set 2 | zhangjiakou
# Processing Record 40 of Set 2 | kruisfontein
# Processing Record 41 of Set 2 | chumikan
# Processing Record 42 of Set 2 | norman wells
# Processing Record 43 of Set 2 | nizhneyansk
# City not found. Skipping...
# Processing Record 44 of Set 2 | avarua
# Processing Record 45 of Set 2 | adrar
# Processing Record 46 of Set 2 | nanortalik
# Processing Record 47 of Set 2 | upernavik
# Processing Record 48 of Set 2 | jamestown
# Processing Record 49 of Set 2 | rawa mazowiecka
# Processing Record 50 of Set 2 | kapaa
# Processing Record 1 of Set 3 | mahebourg
# Processing Record 2 of Set 3 | ponta do sol
# Processing Record 3 of Set 3 | tuatapere
# Processing Record 4 of Set 3 | wadi musa
# Processing Record 5 of Set 3 | calvinia
# Processing Record 6 of Set 3 | bengkulu
# Processing Record 7 of Set 3 | maldonado
# Processing Record 8 of Set 3 | ahuimanu
# Processing Record 9 of Set 3 | luderitz
# Processing Record 10 of Set 3 | victoria
# Processing Record 11 of Set 3 | puerto ayora
# Processing Record 12 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 13 of Set 3 | rancho palos verdes
# Processing Record 14 of Set 3 | verkhoyansk
# Processing Record 15 of Set 3 | eyl
# Processing Record 16 of Set 3 | jiayuguan
# Processing Record 17 of Set 3 | port hardy
# Processing Record 18 of Set 3 | narasannapeta
# Processing Record 19 of Set 3 | isangel
# Processing Record 20 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 21 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 22 of Set 3 | talnakh
# Processing Record 23 of Set 3 | hamilton
# Processing Record 24 of Set 3 | atuona
# Processing Record 25 of Set 3 | akyab
# Processing Record 26 of Set 3 | barrow
# Processing Record 27 of Set 3 | kaitangata
# Processing Record 28 of Set 3 | zhanaozen
# Processing Record 29 of Set 3 | adelaide
# Processing Record 30 of Set 3 | zhigansk
# Processing Record 31 of Set 3 | husavik
# Processing Record 32 of Set 3 | karasjok
# Processing Record 33 of Set 3 | pahalgam
# Processing Record 34 of Set 3 | pali
# Processing Record 35 of Set 3 | salinas
# Processing Record 36 of Set 3 | kota belud
# Processing Record 37 of Set 3 | llanes
# Processing Record 38 of Set 3 | placido de castro
# Processing Record 39 of Set 3 | union
# Processing Record 40 of Set 3 | geraldton
# Processing Record 41 of Set 3 | barentsburg
# City not found. Skipping...
# Processing Record 42 of Set 3 | college
# Processing Record 43 of Set 3 | lagoa
# Processing Record 44 of Set 3 | qaanaaq
# Processing Record 45 of Set 3 | calamar
# Processing Record 46 of Set 3 | severo-kurilsk
# Processing Record 47 of Set 3 | ketchikan
# Processing Record 48 of Set 3 | salalah
# Processing Record 49 of Set 3 | vertou
# Processing Record 50 of Set 3 | saint-philippe
# Processing Record 1 of Set 4 | caronport
# Processing Record 2 of Set 4 | guerrero negro
# Processing Record 3 of Set 4 | kiruna
# Processing Record 4 of Set 4 | belyy yar
# Processing Record 5 of Set 4 | port hedland
# Processing Record 6 of Set 4 | port alfred
# Processing Record 7 of Set 4 | dingle
# Processing Record 8 of Set 4 | alice springs
# Processing Record 9 of Set 4 | kahului
# Processing Record 10 of Set 4 | shingu
# Processing Record 11 of Set 4 | paradwip
# City not found. Skipping...
# Processing Record 12 of Set 4 | kyra
# Processing Record 13 of Set 4 | falealupo
# City not found. Skipping...
# Processing Record 14 of Set 4 | araouane
# Processing Record 15 of Set 4 | alofi
# Processing Record 16 of Set 4 | san miguel
# Processing Record 17 of Set 4 | itabera
# Processing Record 18 of Set 4 | labutta
# City not found. Skipping...
# Processing Record 19 of Set 4 | mount isa
# Processing Record 20 of Set 4 | yar-sale
# Processing Record 21 of Set 4 | sechenovo
# Processing Record 22 of Set 4 | vostok
# Processing Record 23 of Set 4 | taltal
# Processing Record 24 of Set 4 | esperance
# Processing Record 25 of Set 4 | doha
# Processing Record 26 of Set 4 | cochrane
# Processing Record 27 of Set 4 | kavieng
# Processing Record 28 of Set 4 | tuktoyaktuk
# Processing Record 29 of Set 4 | pontianak
# Processing Record 30 of Set 4 | port moresby
# Processing Record 31 of Set 4 | puerto del rosario
# Processing Record 32 of Set 4 | hualmay
# Processing Record 33 of Set 4 | kem
# Processing Record 34 of Set 4 | catuday
# Processing Record 35 of Set 4 | palampur
# Processing Record 36 of Set 4 | qasigiannguit
# Processing Record 37 of Set 4 | dasoguz
# Processing Record 38 of Set 4 | bergen
# Processing Record 39 of Set 4 | banda aceh
# Processing Record 40 of Set 4 | itapora
# Processing Record 41 of Set 4 | saskylakh
# Processing Record 42 of Set 4 | honningsvag
# Processing Record 43 of Set 4 | stornoway
# Processing Record 44 of Set 4 | blagoyevo
# Processing Record 45 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 46 of Set 4 | champerico
# Processing Record 47 of Set 4 | duvan
# Processing Record 48 of Set 4 | chuy
# Processing Record 49 of Set 4 | karakol
# Processing Record 50 of Set 4 | savalou
# Processing Record 1 of Set 5 | vila franca do campo
# Processing Record 2 of Set 5 | yaring
# Processing Record 3 of Set 5 | coquimbo
# Processing Record 4 of Set 5 | manokwari
# Processing Record 5 of Set 5 | eureka
# Processing Record 6 of Set 5 | asau
# Processing Record 7 of Set 5 | hearst
# Processing Record 8 of Set 5 | cayenne
# Processing Record 9 of Set 5 | mangrol
# Processing Record 10 of Set 5 | pisco
# Processing Record 11 of Set 5 | sur
# Processing Record 12 of Set 5 | mar del plata
# Processing Record 13 of Set 5 | hurghada
# Processing Record 14 of Set 5 | kalemie
# Processing Record 15 of Set 5 | bahia blanca
# Processing Record 16 of Set 5 | hithadhoo
# Processing Record 17 of Set 5 | yarega
# Processing Record 18 of Set 5 | rungata
# City not found. Skipping...
# Processing Record 19 of Set 5 | dolzhanskaya
# Processing Record 20 of Set 5 | san luis
# Processing Record 21 of Set 5 | nome
# Processing Record 22 of Set 5 | georgetown
# Processing Record 23 of Set 5 | sorong
# Processing Record 24 of Set 5 | san patricio
# Processing Record 25 of Set 5 | bargal
# City not found. Skipping...
# Processing Record 26 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 27 of Set 5 | casablanca
# Processing Record 28 of Set 5 | hambantota
# Processing Record 29 of Set 5 | quatre cocos
# Processing Record 30 of Set 5 | fort nelson
# Processing Record 31 of Set 5 | qui nhon
# Processing Record 32 of Set 5 | sao lourenco
# Processing Record 33 of Set 5 | bethel
# Processing Record 34 of Set 5 | wenatchee
# Processing Record 35 of Set 5 | ust-ishim
# Processing Record 36 of Set 5 | iskateley
# Processing Record 37 of Set 5 | karratha
# Processing Record 38 of Set 5 | narsaq
# Processing Record 39 of Set 5 | sitka
# Processing Record 40 of Set 5 | dudinka
# Processing Record 41 of Set 5 | port blair
# Processing Record 42 of Set 5 | ahumada
# City not found. Skipping...
# Processing Record 43 of Set 5 | christchurch
# Processing Record 44 of Set 5 | saleaula
# City not found. Skipping...
# Processing Record 45 of Set 5 | celestun
# Processing Record 46 of Set 5 | odweyne
# Processing Record 47 of Set 5 | nyurba
# Processing Record 48 of Set 5 | tiksi
# Processing Record 49 of Set 5 | salinopolis
# Processing Record 50 of Set 5 | viedma
# Processing Record 1 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 2 of Set 6 | samalaeulu
# City not found. Skipping...
# Processing Record 3 of Set 6 | leningradskiy
# Processing Record 4 of Set 6 | yining
# Processing Record 5 of Set 6 | wanning
# Processing Record 6 of Set 6 | arraial do cabo
# Processing Record 7 of Set 6 | lompoc
# Processing Record 8 of Set 6 | rolim de moura
# City not found. Skipping...
# Processing Record 9 of Set 6 | bukama
# Processing Record 10 of Set 6 | qaqortoq
# Processing Record 11 of Set 6 | kutum
# Processing Record 12 of Set 6 | vardo
# Processing Record 13 of Set 6 | srednekolymsk
# Processing Record 14 of Set 6 | cabinda
# Processing Record 15 of Set 6 | mount gambier
# Processing Record 16 of Set 6 | sambava
# Processing Record 17 of Set 6 | samoded
# Processing Record 18 of Set 6 | owando
# Processing Record 19 of Set 6 | clyde river
# Processing Record 20 of Set 6 | riverton
# Processing Record 21 of Set 6 | dumai
# Processing Record 22 of Set 6 | tadine
# Processing Record 23 of Set 6 | katsuura
# Processing Record 24 of Set 6 | praya
# Processing Record 25 of Set 6 | lufilufi
# Processing Record 26 of Set 6 | cabrobo
# Processing Record 27 of Set 6 | hoi an
# Processing Record 28 of Set 6 | kamalasai
# Processing Record 29 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 30 of Set 6 | alyangula
# Processing Record 31 of Set 6 | matelica
# Processing Record 32 of Set 6 | marzuq
# Processing Record 33 of Set 6 | rawson
# Processing Record 34 of Set 6 | lavrentiya
# Processing Record 35 of Set 6 | stepnyak
# Processing Record 36 of Set 6 | ostrovnoy
# Processing Record 37 of Set 6 | teya
# Processing Record 38 of Set 6 | bokoro
# Processing Record 39 of Set 6 | bubaque
# Processing Record 40 of Set 6 | toledo
# Processing Record 41 of Set 6 | west plains
# Processing Record 42 of Set 6 | madarounfa
# Processing Record 43 of Set 6 | upata
# Processing Record 44 of Set 6 | parrita
# Processing Record 45 of Set 6 | axim
# Processing Record 46 of Set 6 | marsh harbour
# Processing Record 47 of Set 6 | grand gaube
# Processing Record 48 of Set 6 | opuwo
# Processing Record 49 of Set 6 | paracatu
# Processing Record 50 of Set 6 | sao joao da barra
# Processing Record 1 of Set 7 | sangar
# Processing Record 2 of Set 7 | alpoyeca
# Processing Record 3 of Set 7 | severnyy
# Processing Record 4 of Set 7 | zabaykalsk
# Processing Record 5 of Set 7 | hyeres
# Processing Record 6 of Set 7 | ganzhou
# Processing Record 7 of Set 7 | cedar city
# Processing Record 8 of Set 7 | skalistyy
# City not found. Skipping...
# Processing Record 9 of Set 7 | attawapiskat
# City not found. Skipping...
# Processing Record 10 of Set 7 | zverinogolovskoye
# Processing Record 11 of Set 7 | aklavik
# Processing Record 12 of Set 7 | karaul
# City not found. Skipping...
# Processing Record 13 of Set 7 | ascension
# Processing Record 14 of Set 7 | mahina
# Processing Record 15 of Set 7 | olinda
# Processing Record 16 of Set 7 | suchil
# Processing Record 17 of Set 7 | kencong
# Processing Record 18 of Set 7 | luba
# Processing Record 19 of Set 7 | karaton
# Processing Record 20 of Set 7 | pangai
# Processing Record 21 of Set 7 | slyudyanka
# Processing Record 22 of Set 7 | lakeside
# Processing Record 23 of Set 7 | muli
# Processing Record 24 of Set 7 | koulamoutou
# Processing Record 25 of Set 7 | khorixas
# Processing Record 26 of Set 7 | fenoarivo
# Processing Record 27 of Set 7 | dikson
# Processing Record 28 of Set 7 | mayskiy
# Processing Record 29 of Set 7 | menongue
# Processing Record 30 of Set 7 | sooke
# Processing Record 31 of Set 7 | beba
# Processing Record 32 of Set 7 | mawlaik
# Processing Record 33 of Set 7 | ciudad bolivar
# Processing Record 34 of Set 7 | saint leonard
# Processing Record 35 of Set 7 | grand river south east
# City not found. Skipping...
# Processing Record 36 of Set 7 | srivardhan
# Processing Record 37 of Set 7 | tahe
# Processing Record 38 of Set 7 | itarema
# Processing Record 39 of Set 7 | aginskoye
# Processing Record 40 of Set 7 | saint george
# Processing Record 41 of Set 7 | sabana de torres
# Processing Record 42 of Set 7 | feijo
# Processing Record 43 of Set 7 | atar
# Processing Record 44 of Set 7 | aljezur
# Processing Record 45 of Set 7 | gympie
# Processing Record 46 of Set 7 | manakara
# Processing Record 47 of Set 7 | ossora
# Processing Record 48 of Set 7 | salisbury
# Processing Record 49 of Set 7 | kuito
# Processing Record 50 of Set 7 | unai
# Processing Record 1 of Set 8 | dodoma
# Processing Record 2 of Set 8 | shenzhen
# Processing Record 3 of Set 8 | sault sainte marie
# Processing Record 4 of Set 8 | saldanha
# Processing Record 5 of Set 8 | kuusamo
# Processing Record 6 of Set 8 | aykhal
# Processing Record 7 of Set 8 | siderno
# Processing Record 8 of Set 8 | newport
# Processing Record 9 of Set 8 | luebo
# Processing Record 10 of Set 8 | hami
# Processing Record 11 of Set 8 | malwan
# City not found. Skipping...
# Processing Record 12 of Set 8 | mehamn
# Processing Record 13 of Set 8 | barroualie
# City not found. Skipping...
# Processing Record 14 of Set 8 | bairiki
# Processing Record 15 of Set 8 | fare
# Processing Record 16 of Set 8 | umzimvubu
# City not found. Skipping...
# Processing Record 17 of Set 8 | jalu
# Processing Record 18 of Set 8 | aripuana
# Processing Record 19 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 20 of Set 8 | bagdarin
# Processing Record 21 of Set 8 | kurilsk
# Processing Record 22 of Set 8 | vicosa do ceara
# Processing Record 23 of Set 8 | playa vicente
# Processing Record 24 of Set 8 | touros
# Processing Record 25 of Set 8 | marivan
# Processing Record 26 of Set 8 | vaitape
# Processing Record 27 of Set 8 | pierre
# Processing Record 28 of Set 8 | shache
# Processing Record 29 of Set 8 | dori
# Processing Record 30 of Set 8 | saint-pierre
# Processing Record 31 of Set 8 | potgietersrus
# City not found. Skipping...
# Processing Record 32 of Set 8 | tilichiki
# Processing Record 33 of Set 8 | birao
# Processing Record 34 of Set 8 | mus
# Processing Record 35 of Set 8 | guicheng
# City not found. Skipping...
# Processing Record 36 of Set 8 | te anau
# Processing Record 37 of Set 8 | half moon bay
# Processing Record 38 of Set 8 | havoysund
# Processing Record 39 of Set 8 | bandarbeyla
# Processing Record 40 of Set 8 | dharchula
# Processing Record 41 of Set 8 | lata
# Processing Record 42 of Set 8 | meadow lake
# Processing Record 43 of Set 8 | millinocket
# Processing Record 44 of Set 8 | kadykchan
# City not found. Skipping...
# Processing Record 45 of Set 8 | ambilobe
# Processing Record 46 of Set 8 | zhanatas
# City not found. Skipping...
# Processing Record 47 of Set 8 | wana
# Processing Record 48 of Set 8 | kenema
# Processing Record 49 of Set 8 | san pedro
# Processing Record 50 of Set 8 | idrinskoye
# Processing Record 1 of Set 9 | brae
# Processing Record 2 of Set 9 | manta
# Processing Record 3 of Set 9 | mahibadhoo
# Processing Record 4 of Set 9 | north bend
# Processing Record 5 of Set 9 | manado
# Processing Record 6 of Set 9 | binalbagan
# Processing Record 7 of Set 9 | fomboni
# Processing Record 8 of Set 9 | tigil
# Processing Record 9 of Set 9 | kochubey
# Processing Record 10 of Set 9 | coihaique
# Processing Record 11 of Set 9 | esna
# Processing Record 12 of Set 9 | margate
# Processing Record 13 of Set 9 | juneau
# Processing Record 14 of Set 9 | tulare
# Processing Record 15 of Set 9 | ulladulla
# Processing Record 16 of Set 9 | armacao dos buzios
# City not found. Skipping...
# Processing Record 17 of Set 9 | alma
# Processing Record 18 of Set 9 | lasem
# Processing Record 19 of Set 9 | yaan
# Processing Record 20 of Set 9 | louisbourg
# City not found. Skipping...
# Processing Record 21 of Set 9 | mikuni
# Processing Record 22 of Set 9 | sao filipe
# Processing Record 23 of Set 9 | alenquer
# Processing Record 24 of Set 9 | zacualpan
# Processing Record 25 of Set 9 | fort saint james
# Processing Record 26 of Set 9 | lorengau
# Processing Record 27 of Set 9 | dyakonovo
# City not found. Skipping...
# Processing Record 28 of Set 9 | kirillov
# Processing Record 29 of Set 9 | chabahar
# Processing Record 30 of Set 9 | baraki barak
# Processing Record 31 of Set 9 | deputatskiy
# Processing Record 32 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 33 of Set 9 | zelenoborskiy
# Processing Record 34 of Set 9 | sakaiminato
# Processing Record 35 of Set 9 | buritama
# Processing Record 36 of Set 9 | elliot
# Processing Record 37 of Set 9 | rudbar
# Processing Record 38 of Set 9 | praia da vitoria
# Processing Record 39 of Set 9 | hay river
# Processing Record 40 of Set 9 | san javier
# Processing Record 41 of Set 9 | valley city
# Processing Record 42 of Set 9 | moose factory
# Processing Record 43 of Set 9 | guaiuba
# Processing Record 44 of Set 9 | berlevag
# Processing Record 45 of Set 9 | snasa
# Processing Record 46 of Set 9 | bandar-e lengeh
# Processing Record 47 of Set 9 | bonavista
# Processing Record 48 of Set 9 | lydenburg
# Processing Record 49 of Set 9 | namatanai
# Processing Record 50 of Set 9 | chalus
# Processing Record 1 of Set 10 | necochea
# Processing Record 2 of Set 10 | flinders
# Processing Record 3 of Set 10 | liaozhong
# Processing Record 4 of Set 10 | khasan
# Processing Record 5 of Set 10 | hailar
# Processing Record 6 of Set 10 | dubbo
# Processing Record 7 of Set 10 | aden
# Processing Record 8 of Set 10 | namuac
# Processing Record 9 of Set 10 | hihifo
# City not found. Skipping...
# Processing Record 10 of Set 10 | nerchinskiy zavod
# Processing Record 11 of Set 10 | zafra
# Processing Record 12 of Set 10 | baiyin
# Processing Record 13 of Set 10 | ust-omchug
# Processing Record 14 of Set 10 | hawalli
# Processing Record 15 of Set 10 | stuttgart
# Processing Record 16 of Set 10 | fremont
# Processing Record 17 of Set 10 | presidente medici
# Processing Record 18 of Set 10 | avera
# Processing Record 19 of Set 10 | belaguntha
# Processing Record 20 of Set 10 | morgan city
# Processing Record 21 of Set 10 | luganville
# Processing Record 22 of Set 10 | kamenka
# Processing Record 23 of Set 10 | moussoro
# Processing Record 24 of Set 10 | henties bay
# Processing Record 25 of Set 10 | mpika
# Processing Record 26 of Set 10 | lam luk ka
# Processing Record 27 of Set 10 | muros
# Processing Record 28 of Set 10 | pevek
# Processing Record 29 of Set 10 | sibolga
# Processing Record 30 of Set 10 | road town
# Processing Record 31 of Set 10 | tambovka
# Processing Record 32 of Set 10 | monrovia
# Processing Record 33 of Set 10 | patos
# Processing Record 34 of Set 10 | galiwinku
# City not found. Skipping...
# Processing Record 35 of Set 10 | guayaramerin
# Processing Record 36 of Set 10 | harwich
# Processing Record 37 of Set 10 | filingue
# Processing Record 38 of Set 10 | san carlos del zulia
# Processing Record 39 of Set 10 | cap malheureux
# Processing Record 40 of Set 10 | porto torres
# Processing Record 41 of Set 10 | mbaiki
# Processing Record 42 of Set 10 | anadyr
# Processing Record 43 of Set 10 | los llanos de aridane
# Processing Record 44 of Set 10 | ahipara
# Processing Record 45 of Set 10 | ngaoundere
# Processing Record 46 of Set 10 | lisala
# Processing Record 47 of Set 10 | bac can
# City not found. Skipping...
# Processing Record 48 of Set 10 | linjiang
# Processing Record 49 of Set 10 | the valley
# Processing Record 50 of Set 10 | bend
# Processing Record 1 of Set 11 | baruun-urt
# Processing Record 2 of Set 11 | norrtalje
# Processing Record 3 of Set 11 | kuryk
# Processing Record 4 of Set 11 | namibe
# Processing Record 5 of Set 11 | durusu
# Processing Record 6 of Set 11 | kaeo
# Processing Record 7 of Set 11 | klaksvik
# Processing Record 8 of Set 11 | chengde
# Processing Record 9 of Set 11 | arrecife
# Processing Record 10 of Set 11 | salihorsk
# Processing Record 11 of Set 11 | harper
# Processing Record 12 of Set 11 | meulaboh
# Processing Record 13 of Set 11 | la ronge
# Processing Record 14 of Set 11 | mayumba
# Processing Record 15 of Set 11 | rosario oeste
# Processing Record 16 of Set 11 | port keats
# Processing Record 17 of Set 11 | merauke
# Processing Record 18 of Set 11 | sedalia
# Processing Record 19 of Set 11 | diu
# Processing Record 20 of Set 11 | megion
# Processing Record 21 of Set 11 | luau
# Processing Record 22 of Set 11 | palauig
# Processing Record 23 of Set 11 | abeche
# Processing Record 24 of Set 11 | naze
# Processing Record 25 of Set 11 | cumberland
# Processing Record 26 of Set 11 | aksarka
# Processing Record 27 of Set 11 | mayo
# Processing Record 28 of Set 11 | ponta delgada
# Processing Record 29 of Set 11 | yulara
# Processing Record 30 of Set 11 | ypsonas
# Processing Record 31 of Set 11 | kieta
# Processing Record 32 of Set 11 | sinkat
# City not found. Skipping...
# Processing Record 33 of Set 11 | vikersund
# Processing Record 34 of Set 11 | barrhead
# Processing Record 35 of Set 11 | huarmey
# Processing Record 36 of Set 11 | belaya gora
# Processing Record 37 of Set 11 | tessalit
# Processing Record 38 of Set 11 | kjollefjord
# Processing Record 39 of Set 11 | lakes entrance
# Processing Record 40 of Set 11 | andilamena
# Processing Record 41 of Set 11 | bitung
# Processing Record 42 of Set 11 | san rafael
# Processing Record 43 of Set 11 | nouadhibou
# Processing Record 44 of Set 11 | davila
# Processing Record 45 of Set 11 | labuhan
# Processing Record 46 of Set 11 | pedernales
# Processing Record 47 of Set 11 | yeppoon
# Processing Record 48 of Set 11 | cerritos
# Processing Record 49 of Set 11 | zvishavane
# Processing Record 50 of Set 11 | kodinsk
# Processing Record 1 of Set 12 | atambua
# Processing Record 2 of Set 12 | palmer
# Processing Record 3 of Set 12 | waingapu
# Processing Record 4 of Set 12 | port hawkesbury
# Processing Record 5 of Set 12 | asgabat
# Processing Record 6 of Set 12 | benguela
# Processing Record 7 of Set 12 | launceston
# Processing Record 8 of Set 12 | bambanglipuro
# Processing Record 9 of Set 12 | iracoubo
# Processing Record 10 of Set 12 | marsa matruh
# Processing Record 11 of Set 12 | pitimbu
# Processing Record 12 of Set 12 | escanaba
# Processing Record 13 of Set 12 | ngukurr
# City not found. Skipping...
# Processing Record 14 of Set 12 | kununurra
# Processing Record 15 of Set 12 | saint-louis
# Processing Record 16 of Set 12 | korla
# Processing Record 17 of Set 12 | visnes
# Processing Record 18 of Set 12 | nsawam
# Processing Record 19 of Set 12 | sao felix do xingu
# Processing Record 20 of Set 12 | weligama
# Processing Record 21 of Set 12 | alekseyevsk
# Processing Record 22 of Set 12 | osoyoos
# Processing Record 23 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 24 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 25 of Set 12 | petrila
# Processing Record 26 of Set 12 | presidente epitacio
# Processing Record 27 of Set 12 | vigrestad
# Processing Record 28 of Set 12 | girvan
# Processing Record 29 of Set 12 | bonthe
# Processing Record 30 of Set 12 | noumea
# Processing Record 31 of Set 12 | macomb
# Processing Record 32 of Set 12 | taraz
# Processing Record 33 of Set 12 | borovoy
# Processing Record 34 of Set 12 | tual
# Processing Record 35 of Set 12 | ballina
# Processing Record 36 of Set 12 | mabaruma
# Processing Record 37 of Set 12 | aswan
# Processing Record 38 of Set 12 | mareeba
# Processing Record 39 of Set 12 | fukue
# Processing Record 40 of Set 12 | luqiao
# Processing Record 41 of Set 12 | ulkan
# Processing Record 42 of Set 12 | karatau
# Processing Record 43 of Set 12 | cam pha
# City not found. Skipping...
# Processing Record 44 of Set 12 | kaseda
# Processing Record 45 of Set 12 | nemuro
# Processing Record 46 of Set 12 | nizhnyaya tavda
# Processing Record 47 of Set 12 | talesh
# City not found. Skipping...
# Processing Record 48 of Set 12 | paamiut
# Processing Record 49 of Set 12 | kentau
# Processing Record 50 of Set 12 | tasbuget
# City not found. Skipping...
# Processing Record 1 of Set 13 | candido mendes
# Processing Record 2 of Set 13 | bumba
# Processing Record 3 of Set 13 | pemangkat
# Processing Record 4 of Set 13 | buluang
# Processing Record 5 of Set 13 | shchelyayur
# City not found. Skipping...
# Processing Record 6 of Set 13 | toliary
# City not found. Skipping...
# Processing Record 7 of Set 13 | yarada
# Processing Record 8 of Set 13 | wad rawah
# Processing Record 9 of Set 13 | baykit
# Processing Record 10 of Set 13 | dovers
# Processing Record 11 of Set 13 | libohove
# Processing Record 12 of Set 13 | berbera
# Processing Record 13 of Set 13 | miles city
# Processing Record 14 of Set 13 | takoradi
# Processing Record 15 of Set 13 | soyo
# Processing Record 16 of Set 13 | olafsvik
# Processing Record 17 of Set 13 | alta floresta
# Processing Record 18 of Set 13 | cornwall
# Processing Record 19 of Set 13 | saint-francois
# Processing Record 20 of Set 13 | hofn
# Processing Record 21 of Set 13 | maragogi
# Processing Record 22 of Set 13 | dali
# Processing Record 23 of Set 13 | solovetskiy
# City not found. Skipping...
# Processing Record 24 of Set 13 | fort-shevchenko
# Processing Record 25 of Set 13 | la gomera
# Processing Record 26 of Set 13 | ilulissat
# Processing Record 27 of Set 13 | vallenar
# Processing Record 28 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 29 of Set 13 | gerash
# Processing Record 30 of Set 13 | alice town
# Processing Record 31 of Set 13 | auki
# Processing Record 32 of Set 13 | waterfoot
# Processing Record 33 of Set 13 | murgab
# Processing Record 34 of Set 13 | wajid
# Processing Record 35 of Set 13 | bin qirdan
# Processing Record 36 of Set 13 | rabo de peixe
# Processing Record 37 of Set 13 | floro
# Processing Record 38 of Set 13 | inuvik
# Processing Record 39 of Set 13 | barbar
# City not found. Skipping...
# Processing Record 40 of Set 13 | ternate
# Processing Record 41 of Set 13 | arlit
# Processing Record 42 of Set 13 | faanui
# Processing Record 43 of Set 13 | birjand
# Processing Record 44 of Set 13 | kupang
# Processing Record 45 of Set 13 | nantucket
# Processing Record 46 of Set 13 | durango
# Processing Record 47 of Set 13 | galgani
# City not found. Skipping...
# Processing Record 48 of Set 13 | hammerfest
# Processing Record 49 of Set 13 | vilcun
# Processing Record 50 of Set 13 | comodoro rivadavia
# Processing Record 1 of Set 14 | cartagena
# Processing Record 2 of Set 14 | cravo norte
# Processing Record 3 of Set 14 | fulitun
# City not found. Skipping...
# Processing Record 4 of Set 14 | namestovo
# Processing Record 5 of Set 14 | umm lajj
# Processing Record 6 of Set 14 | aitape
# Processing Record 7 of Set 14 | puerto madryn
# Processing Record 8 of Set 14 | akhisar
# Processing Record 9 of Set 14 | magdalena
# Processing Record 10 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 11 of Set 14 | antananarivo
# Processing Record 12 of Set 14 | cardston
# Processing Record 13 of Set 14 | jujuy
# City not found. Skipping...
# Processing Record 14 of Set 14 | bara
# Processing Record 15 of Set 14 | goma
# Processing Record 16 of Set 14 | bintulu
# Processing Record 17 of Set 14 | windhoek
# Processing Record 18 of Set 14 | constitucion
# Processing Record 19 of Set 14 | atherton
# Processing Record 20 of Set 14 | hays
# Processing Record 21 of Set 14 | vao
# Processing Record 22 of Set 14 | hovd
# Processing Record 23 of Set 14 | lensk
# Processing Record 24 of Set 14 | gambela
# Processing Record 25 of Set 14 | hohhot
# Processing Record 26 of Set 14 | sarkand
# Processing Record 27 of Set 14 | hue
# Processing Record 28 of Set 14 | toora-khem
# Processing Record 29 of Set 14 | iquitos
# Processing Record 30 of Set 14 | bobo dioulasso
# Processing Record 31 of Set 14 | porta westfalica
# Processing Record 32 of Set 14 | flagstaff
# Processing Record 33 of Set 14 | san joaquin
# Processing Record 34 of Set 14 | cap estate
# Processing Record 35 of Set 14 | lluta
# Processing Record 36 of Set 14 | grand centre
# City not found. Skipping...
# Processing Record 37 of Set 14 | vite
# Processing Record 38 of Set 14 | tias
# Processing Record 39 of Set 14 | kungurtug
# Processing Record 40 of Set 14 | lukoyanov
# Processing Record 41 of Set 14 | krasnyy chikoy
# Processing Record 42 of Set 14 | bom jesus
# Processing Record 43 of Set 14 | kegayli
# City not found. Skipping...
# Processing Record 44 of Set 14 | litoral del san juan
# City not found. Skipping...
# Processing Record 45 of Set 14 | pangoa
# Processing Record 46 of Set 14 | labytnangi
# Processing Record 47 of Set 14 | westport
# Processing Record 48 of Set 14 | qurayyat
# Processing Record 49 of Set 14 | seymchan
# Processing Record 50 of Set 14 | laramie
# Processing Record 1 of Set 15 | roald
# Processing Record 2 of Set 15 | marcona
# City not found. Skipping...
# Processing Record 3 of Set 15 | broome
# Processing Record 4 of Set 15 | poronaysk
# Processing Record 5 of Set 15 | owensboro
# Processing Record 6 of Set 15 | katete
# Processing Record 7 of Set 15 | zyryanovsk
# Processing Record 8 of Set 15 | flin flon
# Processing Record 9 of Set 15 | homer
# Processing Record 10 of Set 15 | lakhdenpokhya
# Processing Record 11 of Set 15 | nokia
# Processing Record 12 of Set 15 | accra
# Processing Record 13 of Set 15 | tevaitoa
# Processing Record 14 of Set 15 | kasongo-lunda
# Processing Record 15 of Set 15 | kilinochchi
# Processing Record 16 of Set 15 | wasilla
# Processing Record 17 of Set 15 | kamina
# Processing Record 18 of Set 15 | burica
# City not found. Skipping...
# Processing Record 19 of Set 15 | panjakent
# Processing Record 20 of Set 15 | bereda
# Processing Record 21 of Set 15 | andenes
# Processing Record 22 of Set 15 | madingou
# Processing Record 23 of Set 15 | warmbad
# Processing Record 24 of Set 15 | diego de almagro
# Processing Record 25 of Set 15 | lepe
# Processing Record 26 of Set 15 | oranjemund
# Processing Record 27 of Set 15 | dunedin
# Processing Record 28 of Set 15 | brandon
# Processing Record 29 of Set 15 | chicama
# Processing Record 30 of Set 15 | mrirt
# City not found. Skipping...
# Processing Record 31 of Set 15 | ixtapa
# Processing Record 32 of Set 15 | arzgir
# Processing Record 33 of Set 15 | baltoji voke
# Processing Record 34 of Set 15 | verkhnevilyuysk
# Processing Record 35 of Set 15 | ouallam
# Processing Record 36 of Set 15 | maniitsoq
# Processing Record 37 of Set 15 | ishigaki
# Processing Record 38 of Set 15 | batagay-alyta
# Processing Record 39 of Set 15 | rumoi
# Processing Record 40 of Set 15 | koslan
# Processing Record 41 of Set 15 | salta
# Processing Record 42 of Set 15 | sompeta
# Processing Record 43 of Set 15 | ust-koksa
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
len(city_data)
# Out:
# 682

# %%
print(city_url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=992818bd3c13312a62056673a26359c6&q=ust-koksa

# %%
deliverable_1_dataframe = pd.DataFrame(city_data)
deliverable_1_dataframe.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0       Mataura      NZ -46.1927  168.8643     48.47        92          94
# 1  Nizhniy Odes      RU  63.6445   54.8560     67.19        54          79
# 2       Sepatan      ID  -6.1189  106.5750     92.53        66          20
# 3        Laguna      US  38.4210 -121.4238     66.49        81           1
# 4      Tasiilaq      GL  65.6145  -37.6368     42.96        72           0
# 5    Talcahuano      CL -36.7167  -73.1167     54.54        88         100
# 6       Rikitea      PF -23.1203 -134.9692     75.61        83         100
# 7          Lebu      CL -37.6167  -73.6500     54.12        93         100
# 8  Oktyabrskoye      RU  43.0645   44.7417     80.74        54          31
# 9     Carnarvon      AU -24.8667  113.6333     63.75        52           0
#
#    Wind Speed Current Description
# 0        5.26     overcast clouds
# 1        3.53       broken clouds
# 2        8.99          few clouds
# 3        4.00           clear sky
# 4        6.64           clear sky
# 5        8.88     overcast clouds
# 6       13.09     overcast clouds
# 7       12.08          light rain
# 8        4.47    scattered clouds
# 9       18.32           clear sky

# %%
output_data_file = "WeatherPy_Database.csv"

# %%
deliverable_1_dataframe.to_csv(output_data_file, index_label="City_ID")
